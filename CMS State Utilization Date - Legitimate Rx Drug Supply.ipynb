# %%
import numpy as np
import pandas as pd
from datetime import datetime
import timestring
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We have two datasets here from the CMS State Drug Utilization Set
# <li>CMS State Drug Utilization Data 2017<br>
# <li>CMS State Drug Utilization Data 2016
# <li>Ref for product codes: https://data.medicaid.gov/State-Drug-Utilization/State-Drug-Utilization-Data-2016/3v6v-qk5s
# <li>About CMS Product Codes:
# <li>Labeler Code: First segment of NDC that identifies the manufacturer, labeler, relabeler, packager, repackager or distributor of the drug.
# <li>Product Code: Second segment of NDC.
# <li>Package Size Code: Third segment of NDC.

# %% [markdown]
# Drug names for opioids:<br>
#
# REFERENCE: http://www.rehabcenter.net/list-opioids-united-states/
#
# Brand Name Opioid Prescriptions:
#
# For this dataset, you need to look up and filter down the opioid-related drugs. If you do this through
# the Product Name, I used this set of opioid Rx drugs:
#
# <li>Abstral (fentanyl)
# <li>Actiq (fentanyl)
# <li>Avinza (morphine sulfate extended-release capsules)
# <li>Butrans (buprenorphine transdermal system)
# <li>Demerol (meperidine [also known as isonipecaine or pethidine])
# <li>Dilaudid (hydromorphone [also known as dihydromorphinone])
# <li>Dolophine (methadone hydrochloride tablets)
# <li>Duragesic (fentanyl transdermal system)
# <li>Fentora (fentanyl)
# <li>Hysingla (hydrocodone)
# <li>Methadose (methadone)
# <li>Morphabond (morphine)
# <li>Nucynta ER (tapentadol extended-release oral tablets)
# <li>Onsolis (fentanyl)
# <li>Oramorph (morphine)
# <li>Oxaydo (oxycodone)
# <li>Roxanol-T (morphine)
# <li>Sublimaze (fentanyl)
# <li>Xtampza ER (oxycodone)
# <li>Zohydro ER (hydrocodone)
#
# Combination Opioid Prescriptions:<br>
#
# <li>Anexsia (hydrocodone containing acetaminophen)
# <li>Co-Gesic (hydrocodone containing acetaminophen)
# <li>Embeda (morphine sulfate and naltrexone extended-release capsules)
# <li>Exalgo (hydromorphone hydrochloride extended-release tablets)
# <li>Hycet (hydrocodone containing acetaminophen)
# <li>Hycodan (hydrocodone containing homatropine)
# <li>Hydromet (hydrocodone containing homatropine)
# <li>Ibudone (hydrocodone containing ibuprofen)
# <li>Kadian (morphine sulfate extended-release tablets)
# <li>Liquicet (hydrocodone containing acetaminophen)
# <li>Lorcet (hydrocodone containing acetaminophen)
# <li>Lorcet Plus (hydrocodone containing acetaminophen)
# <li>Lortab (hydrocodone containing acetaminophen)
# <li>Maxidone (hydrocodone containing acetaminophen)
# <li>MS Contin (morphine sulfate controlled-release tablets)
# <li>Norco (hydrocodone containing acetaminophen)
# <li>Opana ER (oxymorphone hydrochloride extended-release tablets)
# <li>OxyContin (oxycodone hydrochloride controlled-release tablets)
# <li>Oxycet (oxycodone containing acetaminophen)
# <li>Palladone (hydromorphone hydrochloride extended-release capsules)
# <li>Percocet (oxycodone containing acetaminophen)
# <li>Percodan (oxycodone containing aspirin)
# <li>Reprexain (hydrocodone containing ibuprofen)
# <li>Rezira (hydrocodone containing pseudoephedrine)
# <li>Roxicet (oxycodone containing acetaminophen)
# <li>Targiniq ER (oxycodone containing naloxone)
# <li>TussiCaps (hydrocodone containing chlorpheniramine)
# <li>Tussionex (hydrocodone containing chlorpheniramine)
# <li>Tuzistra XR (codeine containing chlorpheniramine)
# <li>Tylenol #3 and #4 (codeine containing acetaminophen)
# <li>Vicodin (hydrocodone containing acetaminophen)
# <li>Vicodin ES (hydrocodone containing acetaminophen)
# <li>Vicodin HP (hydrocodone containing acetaminophen)
# <li>Vicoprofen (hydrocodone containing ibuprofen)
# <li>Vituz (hydrocodone containing chlorpheniramine)
# <li>Xartemis XR (oxycodone containing acetaminophen)
# <li>Xodol (hydrocodone containing acetaminophen)
# <li>Zolvit (hydrocodone containing acetaminophen)
# <li>Zutripro (hydrocodone containing chlorpheniramine and pseudoephedrine)
# <li>Zydone (hydrocodone containing acetaminophen)
#
# Generic: <br>
#
# <li>Fentanyl (fentanyl extended-release transdermal system)
# <li>Methadone hydrochloride (methadone hydrochloride tablets, methadone hydrochloride oral solution)
# <li>Morphine sulfate (morphine sulfate extended-release capsules, morphine sulfate extended-release tablets)
# <li>Oxymorphone hydrochloride (oxymorphone hydrochloride extended-release tablets)

# %%
#CMS
cms_2017 = pd.read_csv("/Users/catherineordun/Documents/Hackathon/DHHS/ready_data/State_Drug_Utilization_Data_2017.csv")
print(cms_2017.shape) #(2343727, 20)
cms_2017.dtypes
# Out:
# (2343727, 20)
# Utilization Type                   object
# State                              object
# Labeler Code                        int64
# Product Code                        int64
# Package Size                        int64
# Year                                int64
# Quarter                             int64
# Product Name                       object
# Suppression Used                     bool
# Units Reimbursed                  float64
# Number of Prescriptions           float64
# Total Amount Reimbursed           float64
# Medicaid Amount Reimbursed        float64
# Non Medicaid Amount Reimbursed    float64
# Quarter Begin                      object
# Quarter Begin Date                 object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# NDC                                 int64
# dtype: object

# %%
cms_2017.rename(columns={
        'Labeler Code':'label_code',
        'Product Code':'product_code',
        'Package Size':'package_size',
        'Product Name':'product_name',
        'Suppression Used':'suppression',
        'Units Reimbursed':'units_reimb',
        'Number of Prescriptions':'num_rx',
        'Total Amount Reimbursed':'total_amt_reimb',
        'Medicaid Amount Reimbursed':'med_amt_reimb',
        'Non Medicaid Amount Reimbursed':'nonmed_amt_reimb',
        'Quarter Begin':'qtr_begin', 
        'Quarter Begin Date':'qtr_begin_date'},inplace=True)

# %%
cms_2017.loc[(cms_2017["product_name"] == "PERCOCET")]
# Out:
#         Utilization Type State  label_code  product_code  package_size  Year  \
# 84839               MCOU    XX       63481           627            70  2017
# 118099              FFSU    NC       63481           623            70  2017
# 169729              MCOU    NH       63481           629            70  2017
# 272821              FFSU    MN       63481           623            70  2017
# 311125              MCOU    MN       63481           623            70  2017
# 356253              FFSU    MO       63481           623            70  2017
# 362239              FFSU    CO       63481           628            70  2017
# 372935              MCOU    MN       63481           627            70  2017
# 384674              FFSU    NC       63481           628            70  2017
# 447304              FFSU    XX       63481           623            85  2017
# 468636              MCOU    KY       63481           623            85  2017
# 488994              MCOU    FL       63481           629            70  2017
# 546028              MCOU    FL       63481           623            70  2017
# 617166              FFSU    KY       63481           623            85  2017
# 622136              MCOU    NH       63481           628            70  2017
# 714198              MCOU    AZ       63481           623            70  2017
# 750483              FFSU    MN       63481           629            70  2017
# 753482              FFSU    NC       63481           629            70  2017
# 779988              MCOU    MI       63481           629            70  2017
# 919401              FFSU    KY       63481           623            85  2017
# 971294              FFSU    MO       63481           623            70  2017
# 1045691             MCOU    FL       63481           623            70  2017
# 1087263             FFSU    NC       63481           629            70  2017
# 1106830             FFSU    NC       63481           623            70  2017
# 1215471             MCOU    NH       63481           628            70  2017
# 1240532             MCOU    KY       63481           623            85  2017
# 1283047             FFSU    NH       63481           623            70  2017
# 1446596             FFSU    CO       63481           628            70  2017
# 1586055             MCOU    FL       63481           629            70  2017
# 1616465             FFSU    MI       63481           623            70  2017
# 1643733             MCOU    MI       63481           629            70  2017
# 1697886             MCOU    MN       63481           623            70  2017
# 1892110             FFSU    MN       63481           623            70  2017
# 1913831             MCOU    NH       63481           629            70  2017
# 1933971             FFSU    MN       63481           629            70  2017
# 2025877             MCOU    MN       63481           629            70  2017
# 2112221             MCOU    AZ       63481           623            70  2017
# 2156528             MCOU    AZ       63481           629            70  2017
#
#          Quarter product_name  suppression  units_reimb  num_rx  \
# 84839          1     PERCOCET         True          NaN     NaN
# 118099         1     PERCOCET         True          NaN     NaN
# 169729         1     PERCOCET         True          NaN     NaN
# 272821         1     PERCOCET         True          NaN     NaN
# 311125         1     PERCOCET         True          NaN     NaN
# 356253         1     PERCOCET         True          NaN     NaN
# 362239         1     PERCOCET         True          NaN     NaN
# 372935         1     PERCOCET         True          NaN     NaN
# 384674         1     PERCOCET         True          NaN     NaN
# 447304         1     PERCOCET         True          NaN     NaN
# 468636         1     PERCOCET         True          NaN     NaN
# 488994         1     PERCOCET         True          NaN     NaN
# 546028         1     PERCOCET         True          NaN     NaN
# 617166         1     PERCOCET         True          NaN     NaN
# 622136         1     PERCOCET         True          NaN     NaN
# 714198         1     PERCOCET         True          NaN     NaN
# 750483         1     PERCOCET         True          NaN     NaN
# 753482         1     PERCOCET         True          NaN     NaN
# 779988         1     PERCOCET         True          NaN     NaN
# 919401         2     PERCOCET         True          NaN     NaN
# 971294         2     PERCOCET         True          NaN     NaN
# 1045691        2     PERCOCET         True          NaN     NaN
# 1087263        2     PERCOCET         True          NaN     NaN
# 1106830        2     PERCOCET         True          NaN     NaN
# 1215471        2     PERCOCET         True          NaN     NaN
# 1240532        2     PERCOCET         True          NaN     NaN
# 1283047        2     PERCOCET         True          NaN     NaN
# 1446596        2     PERCOCET         True          NaN     NaN
# 1586055        2     PERCOCET         True          NaN     NaN
# 1616465        2     PERCOCET         True          NaN     NaN
# 1643733        2     PERCOCET         True          NaN     NaN
# 1697886        2     PERCOCET         True          NaN     NaN
# 1892110        2     PERCOCET         True          NaN     NaN
# 1913831        2     PERCOCET         True          NaN     NaN
# 1933971        2     PERCOCET         True          NaN     NaN
# 2025877        2     PERCOCET         True          NaN     NaN
# 2112221        2     PERCOCET         True          NaN     NaN
# 2156528        1     PERCOCET         True          NaN     NaN
#
#          total_amt_reimb  med_amt_reimb  nonmed_amt_reimb qtr_begin  \
# 84839                NaN            NaN               NaN       1/1
# 118099               NaN            NaN               NaN       1/1
# 169729               NaN            NaN               NaN       1/1
# 272821               NaN            NaN               NaN       1/1
# 311125               NaN            NaN               NaN       1/1
# 356253               NaN            NaN               NaN       1/1
# 362239               NaN            NaN               NaN       1/1
# 372935               NaN            NaN               NaN       1/1
# 384674               NaN            NaN               NaN       1/1
# 447304               NaN            NaN               NaN       1/1
# 468636               NaN            NaN               NaN       1/1
# 488994               NaN            NaN               NaN       1/1
# 546028               NaN            NaN               NaN       1/1
# 617166               NaN            NaN               NaN       1/1
# 622136               NaN            NaN               NaN       1/1
# 714198               NaN            NaN               NaN       1/1
# 750483               NaN            NaN               NaN       1/1
# 753482               NaN            NaN               NaN       1/1
# 779988               NaN            NaN               NaN       1/1
# 919401               NaN            NaN               NaN       4/1
# 971294               NaN            NaN               NaN       4/1
# 1045691              NaN            NaN               NaN       4/1
# 1087263              NaN            NaN               NaN       4/1
# 1106830              NaN            NaN               NaN       4/1
# 1215471              NaN            NaN               NaN       4/1
# 1240532              NaN            NaN               NaN       4/1
# 1283047              NaN            NaN               NaN       4/1
# 1446596              NaN            NaN               NaN       4/1
# 1586055              NaN            NaN               NaN       4/1
# 1616465              NaN            NaN               NaN       4/1
# 1643733              NaN            NaN               NaN       4/1
# 1697886              NaN            NaN               NaN       4/1
# 1892110              NaN            NaN               NaN       4/1
# 1913831              NaN            NaN               NaN       4/1
# 1933971              NaN            NaN               NaN       4/1
# 2025877              NaN            NaN               NaN       4/1
# 2112221              NaN            NaN               NaN       4/1
# 2156528              NaN            NaN               NaN       1/1
#
#                  qtr_begin_date  Latitude  Longitude              Location  \
# 84839    01/01/2017 12:00:00 AM       NaN        NaN                   NaN
# 118099   01/01/2017 12:00:00 AM   35.6411   -79.8431   (35.6411, -79.8431)
# 169729   01/01/2017 12:00:00 AM   43.4108   -71.5653   (43.4108, -71.5653)
# 272821   01/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 311125   01/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 356253   01/01/2017 12:00:00 AM   38.4623   -92.3020    (38.4623, -92.302)
# 362239   01/01/2017 12:00:00 AM   39.0646  -105.3272  (39.0646, -105.3272)
# 372935   01/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 384674   01/01/2017 12:00:00 AM   35.6411   -79.8431   (35.6411, -79.8431)
# 447304   01/01/2017 12:00:00 AM       NaN        NaN                   NaN
# 468636   01/01/2017 12:00:00 AM   37.6690   -84.6514    (37.669, -84.6514)
# 488994   01/01/2017 12:00:00 AM   27.8333   -81.7170    (27.8333, -81.717)
# 546028   01/01/2017 12:00:00 AM   27.8333   -81.7170    (27.8333, -81.717)
# 617166   01/01/2017 12:00:00 AM   37.6690   -84.6514    (37.669, -84.6514)
# 622136   01/01/2017 12:00:00 AM   43.4108   -71.5653   (43.4108, -71.5653)
# 714198   01/01/2017 12:00:00 AM   33.7712  -111.3877  (33.7712, -111.3877)
# 750483   01/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 753482   01/01/2017 12:00:00 AM   35.6411   -79.8431   (35.6411, -79.8431)
# 779988   01/01/2017 12:00:00 AM   43.3504   -84.5603   (43.3504, -84.5603)
# 919401   04/01/2017 12:00:00 AM   37.6690   -84.6514    (37.669, -84.6514)
# 971294   04/01/2017 12:00:00 AM   38.4623   -92.3020    (38.4623, -92.302)
# 1045691  04/01/2017 12:00:00 AM   27.8333   -81.7170    (27.8333, -81.717)
# 1087263  04/01/2017 12:00:00 AM   35.6411   -79.8431   (35.6411, -79.8431)
# 1106830  04/01/2017 12:00:00 AM   35.6411   -79.8431   (35.6411, -79.8431)
# 1215471  04/01/2017 12:00:00 AM   43.4108   -71.5653   (43.4108, -71.5653)
# 1240532  04/01/2017 12:00:00 AM   37.6690   -84.6514    (37.669, -84.6514)
# 1283047  04/01/2017 12:00:00 AM   43.4108   -71.5653   (43.4108, -71.5653)
# 1446596  04/01/2017 12:00:00 AM   39.0646  -105.3272  (39.0646, -105.3272)
# 1586055  04/01/2017 12:00:00 AM   27.8333   -81.7170    (27.8333, -81.717)
# 1616465  04/01/2017 12:00:00 AM   43.3504   -84.5603   (43.3504, -84.5603)
# 1643733  04/01/2017 12:00:00 AM   43.3504   -84.5603   (43.3504, -84.5603)
# 1697886  04/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 1892110  04/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 1913831  04/01/2017 12:00:00 AM   43.4108   -71.5653   (43.4108, -71.5653)
# 1933971  04/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 2025877  04/01/2017 12:00:00 AM   45.7326   -93.9196   (45.7326, -93.9196)
# 2112221  04/01/2017 12:00:00 AM   33.7712  -111.3877  (33.7712, -111.3877)
# 2156528  01/01/2017 12:00:00 AM   33.7712  -111.3877  (33.7712, -111.3877)
#
#                  NDC
# 84839    63481062770
# 118099   63481062370
# 169729   63481062970
# 272821   63481062370
# 311125   63481062370
# 356253   63481062370
# 362239   63481062870
# 372935   63481062770
# 384674   63481062870
# 447304   63481062385
# 468636   63481062385
# 488994   63481062970
# 546028   63481062370
# 617166   63481062385
# 622136   63481062870
# 714198   63481062370
# 750483   63481062970
# 753482   63481062970
# 779988   63481062970
# 919401   63481062385
# 971294   63481062370
# 1045691  63481062370
# 1087263  63481062970
# 1106830  63481062370
# 1215471  63481062870
# 1240532  63481062385
# 1283047  63481062370
# 1446596  63481062870
# 1586055  63481062970
# 1616465  63481062370
# 1643733  63481062970
# 1697886  63481062370
# 1892110  63481062370
# 1913831  63481062970
# 1933971  63481062970
# 2025877  63481062970
# 2112221  63481062370
# 2156528  63481062970

# %% [markdown]
# You'll notice here that the Labeler Code + Product Code is equal to in the
# nda_product file the following:
#
# <li>PRODUCTNDC: 57881-332
#
# In order to determine the packagem dosage, and manufacturer, you need to merge together the product
# and package files from the NDA at FDA.

# %%
#this is a different dataset from the FDA
nda_product = pd.read_csv("/Users/catherineordun/Documents/Hackathon/DHHS/nda_product.csv")

# %%
nda_product.head()
# Out:
#                                         PRODUCTID PRODUCTNDC PRODUCTTYPENAME  \
# 0  0363-0810_298b1eeb-c214-4d67-8c7f-4682bac2cf23  0363-0810  HUMAN OTC DRUG
# 1  0574-0067_cba29e3c-d446-4a70-928a-c98ed8eedcc6  0574-0067  HUMAN OTC DRUG
# 2  11673-810_fe48f8bd-77f0-487b-b24f-217a3601fd62  11673-810  HUMAN OTC DRUG
# 3  37012-810_3eedb9fd-22af-4650-b110-459d644f47dd  37012-810  HUMAN OTC DRUG
# 4  37808-810_e723ebfd-b701-4f61-aedc-d6d93d277ac8  37808-810  HUMAN OTC DRUG
#
#   PROPRIETARYNAME PROPRIETARYNAMESUFFIX NONPROPRIETARYNAME DOSAGEFORMNAME  \
# 0             70%                   NaN  Isopropyl alcohol         LIQUID
# 1             70%                   NaN  Isopropyl alcohol         LIQUID
# 2             70%                   NaN  Isopropyl alcohol         LIQUID
# 3             70%                   NaN  Isopropyl alcohol         LIQUID
# 4             70%                   NaN  Isopropyl alcohol         LIQUID
#
#   ROUTENAME  STARTMARKETINGDATE  ENDMARKETINGDATE    MARKETINGCATEGORYNAME  \
# 0   TOPICAL          19891015.0               NaN  OTC MONOGRAPH NOT FINAL
# 1   TOPICAL          20140414.0               NaN  OTC MONOGRAPH NOT FINAL
# 2   TOPICAL          19890715.0               NaN  OTC MONOGRAPH NOT FINAL
# 3   TOPICAL          20080102.0               NaN  OTC MONOGRAPH NOT FINAL
# 4   TOPICAL          20150618.0               NaN  OTC MONOGRAPH NOT FINAL
#
#   APPLICATIONNUMBER                 LABELERNAME      SUBSTANCENAME  \
# 0          part333A              Walgreens, CO.  ISOPROPYL ALCOHOL
# 1          part333A   Paddock Laboratories, LLC  ISOPROPYL ALCOHOL
# 2          part333A               Target Corp.,  ISOPROPYL ALCOHOL
# 3          part333A  Shopko Stores Operating Co  ISOPROPYL ALCOHOL
# 4          part333A                       H-E-B  ISOPROPYL ALCOHOL
#
#   ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT PHARM_CLASSES DEASCHEDULE
# 0                       500              mg/mL           NaN         NaN
# 1                       500              mg/mL           NaN         NaN
# 2                       500              mg/mL           NaN         NaN
# 3                       500              mg/mL           NaN         NaN
# 4                       500              mg/mL           NaN         NaN

# %% [markdown]
# Steps:<br>
# #1. Now, we need to extract out from the cms_2017 file, all the drugs that are opioid drugs
# #2. Create a new field called PRODUCTNDC
# #3. And merge with nda_product to get the dosage and manufacturer name
# #4. Convert the 'STARTMARKETINGDATE' from float -> datetime

# %%
#these are all the drugs listed above in a csv
druglist= pd.read_csv("/Users/catherineordun/Documents/Hackathon/DHHS/druglist.csv")

# %%
druglist.head()
# Out:
#    Abstral
# 0  Abstral
# 1    Actiq
# 2   Avinza
# 3  Butrans
# 4  Demerol

# %%
#flatten to remove it as a list of lists
searchlist = druglist.values.T.flatten()

# %%
searchlist
# Out:
# array(['Abstral', 'Actiq', 'Avinza', 'Butrans', 'Demerol', 'Dilaudid',
#        'Dolophine', 'Duragesic', 'Fentora', 'Hysingla', 'Methadose',
#        'Morphabond', 'Nucynta ER', 'Onsolis', 'Oramorph', 'Oxaydo',
#        'Roxanol-T', 'Sublimaze', 'Xtampza', 'Zohydro', 'Anexsia',
#        'Co-Gesic', 'Embeda', 'Exalgo', 'Hycet', 'Hycodan', 'Hydromet',
#        'Ibudone', 'Kadian', 'Liquicet', 'Lorcet', 'Lorcet Plus', 'Lortab',
#        'Maxidone', 'MS Contin', 'Norco', 'Opana ER', 'OxyContin', 'Oxycet',
#        'Palladone', 'Percocet', 'Percodan', 'Reprexain', 'Rezira',
#        'Roxicet', 'Targiniq ER', 'TussiCaps', 'Tussionex', 'Tuzistra XR',
#        'Tylenol 3', 'Tylenol 4', 'Vicodin', 'Vicodin ES', 'Vicodin HP',
#        'Vicoprofen', 'Vituz', 'Xartemis XR', 'Xodol', 'Zolvit', 'Zutripro',
#        'Zydone', 'Fentanyl', 'Methadone hydrochloride', 'Morphine sulfate',
#        'Oxymorphone hydrochloride'], dtype=object)

# %%
#capitalize all drug names in searchlist b/c the product_name is all capitalized
cap_searchlist = [element.upper() for element in searchlist]

# %%
#make sure all the product_names are capitalized in the dataframe so we get everything 
cms_2017['product_name'] = map(lambda x: str(x).upper(), cms_2017['product_name'])

# %%
#now search through to find a match
cms_2017_opioids = cms_2017.query('product_name in @cap_searchlist')
print(cms_2017_opioids['product_name'].nunique()) #33
print(len(searchlist)) #65
# Out:
# 33
# 65

# %%
#make a new column called 'PRODUCTNDC'
cms_2017_opioids['PRODUCTNDC'] = cms_2017_opioids['label_code'].astype(str) + '-' +cms_2017_opioids['product_code'].astype(str)
# Out:
# /Users/catherineordun/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#check it's right
cms_2017_opioids.loc[(cms_2017_opioids["product_name"] == "ABSTRAL")] #ok it works
# Out:
#         Utilization Type State  label_code  product_code  package_size  Year  \
# 1065170             FFSU    MO       57881           332            32  2017
# 2205338             FFSU    XX       57881           332            32  2017
#
#          Quarter product_name  suppression  units_reimb     ...      \
# 1065170        2      ABSTRAL         True          NaN     ...
# 2205338        2      ABSTRAL         True          NaN     ...
#
#          total_amt_reimb  med_amt_reimb  nonmed_amt_reimb  qtr_begin  \
# 1065170              NaN            NaN               NaN        4/1
# 2205338              NaN            NaN               NaN        4/1
#
#                  qtr_begin_date Latitude  Longitude            Location  \
# 1065170  04/01/2017 12:00:00 AM  38.4623    -92.302  (38.4623, -92.302)
# 2205338  04/01/2017 12:00:00 AM      NaN        NaN                 NaN
#
#                  NDC  PRODUCTNDC
# 1065170  57881033232   57881-332
# 2205338  57881033232   57881-332
#
# [2 rows x 21 columns]

# %%
nda_product.loc[(nda_product["PRODUCTNDC"] == "409-1201")] #there are products in CMS that aren't in the NDA products

#for example, the above 409-1201 is demerol and demerol is not in the nda PRODUCTS table
cms_2017_opioids.loc[(cms_2017_opioids["PRODUCTNDC"] == "409-1201")] #ok it works
# Out:
#         Utilization Type State  label_code  product_code  package_size  Year  \
# 34099               MCOU    KY         409          1201            20  2017
# 304760              FFSU    SC         409          1201            20  2017
# 378029              FFSU    TN         409          1201            20  2017
# 535681              MCOU    MN         409          1201            20  2017
# 563779              MCOU    SC         409          1201            20  2017
# 616224              FFSU    NC         409          1201            20  2017
# 658637              MCOU    TN         409          1201            20  2017
# 1029239             MCOU    MN         409          1201            20  2017
# 1035148             MCOU    SC         409          1201            20  2017
# 1116803             FFSU    NC         409          1201            20  2017
# 1318795             MCOU    KY         409          1201            20  2017
# 1636942             FFSU    MI         409          1201            20  2017
# 1901828             MCOU    TN         409          1201            20  2017
# 1991757             FFSU    AK         409          1201            20  2017
# 2078793             FFSU    MI         409          1201            20  2017
# 2120868             FFSU    TN         409          1201            20  2017
# 2330619             FFSU    AK         409          1201            20  2017
#
#          Quarter product_name  suppression  units_reimb     ...      \
# 34099          1      DEMEROL         True          NaN     ...
# 304760         1      DEMEROL         True          NaN     ...
# 378029         1      DEMEROL        False         49.0     ...
# 535681         1      DEMEROL         True          NaN     ...
# 563779         1      DEMEROL         True          NaN     ...
# 616224         1      DEMEROL         True          NaN     ...
# 658637         1      DEMEROL         True          NaN     ...
# 1029239        2      DEMEROL         True          NaN     ...
# 1035148        2      DEMEROL         True          NaN     ...
# 1116803        2      DEMEROL         True          NaN     ...
# 1318795        2      DEMEROL         True          NaN     ...
# 1636942        1      DEMEROL        False         18.0     ...
# 1901828        2      DEMEROL         True          NaN     ...
# 1991757        2      DEMEROL         True          NaN     ...
# 2078793        2      DEMEROL         True          NaN     ...
# 2120868        2      DEMEROL        False         16.0     ...
# 2330619        1      DEMEROL         True          NaN     ...
#
#          total_amt_reimb  med_amt_reimb  nonmed_amt_reimb  qtr_begin  \
# 34099                NaN            NaN               NaN        1/1
# 304760               NaN            NaN               NaN        1/1
# 378029             23.30          23.30              0.00        1/1
# 535681               NaN            NaN               NaN        1/1
# 563779               NaN            NaN               NaN        1/1
# 616224               NaN            NaN               NaN        1/1
# 658637               NaN            NaN               NaN        1/1
# 1029239              NaN            NaN               NaN        4/1
# 1035148              NaN            NaN               NaN        4/1
# 1116803              NaN            NaN               NaN        4/1
# 1318795              NaN            NaN               NaN        4/1
# 1636942            82.10          36.26             45.84        1/1
# 1901828              NaN            NaN               NaN        4/1
# 1991757              NaN            NaN               NaN        4/1
# 2078793              NaN            NaN               NaN        4/1
# 2120868             4.07           4.07              0.00        4/1
# 2330619              NaN            NaN               NaN        1/1
#
#                  qtr_begin_date Latitude  Longitude             Location  \
# 34099    01/01/2017 12:00:00 AM  37.6690   -84.6514   (37.669, -84.6514)
# 304760   01/01/2017 12:00:00 AM  33.8191   -80.9066  (33.8191, -80.9066)
# 378029   01/01/2017 12:00:00 AM  35.7449   -86.7489  (35.7449, -86.7489)
# 535681   01/01/2017 12:00:00 AM  45.7326   -93.9196  (45.7326, -93.9196)
# 563779   01/01/2017 12:00:00 AM  33.8191   -80.9066  (33.8191, -80.9066)
# 616224   01/01/2017 12:00:00 AM  35.6411   -79.8431  (35.6411, -79.8431)
# 658637   01/01/2017 12:00:00 AM  35.7449   -86.7489  (35.7449, -86.7489)
# 1029239  04/01/2017 12:00:00 AM  45.7326   -93.9196  (45.7326, -93.9196)
# 1035148  04/01/2017 12:00:00 AM  33.8191   -80.9066  (33.8191, -80.9066)
# 1116803  04/01/2017 12:00:00 AM  35.6411   -79.8431  (35.6411, -79.8431)
# 1318795  04/01/2017 12:00:00 AM  37.6690   -84.6514   (37.669, -84.6514)
# 1636942  01/01/2017 12:00:00 AM  43.3504   -84.5603  (43.3504, -84.5603)
# 1901828  04/01/2017 12:00:00 AM  35.7449   -86.7489  (35.7449, -86.7489)
# 1991757  04/01/2017 12:00:00 AM  61.3850  -152.2683  (61.385, -152.2683)
# 2078793  04/01/2017 12:00:00 AM  43.3504   -84.5603  (43.3504, -84.5603)
# 2120868  04/01/2017 12:00:00 AM  35.7449   -86.7489  (35.7449, -86.7489)
# 2330619  01/01/2017 12:00:00 AM  61.3850  -152.2683  (61.385, -152.2683)
#
#                NDC  PRODUCTNDC
# 34099    409120120    409-1201
# 304760   409120120    409-1201
# 378029   409120120    409-1201
# 535681   409120120    409-1201
# 563779   409120120    409-1201
# 616224   409120120    409-1201
# 658637   409120120    409-1201
# 1029239  409120120    409-1201
# 1035148  409120120    409-1201
# 1116803  409120120    409-1201
# 1318795  409120120    409-1201
# 1636942  409120120    409-1201
# 1901828  409120120    409-1201
# 1991757  409120120    409-1201
# 2078793  409120120    409-1201
# 2120868  409120120    409-1201
# 2330619  409120120    409-1201
#
# [17 rows x 21 columns]

# %% [markdown]
# <b>MERGE FDA AND CMS</b>

# %%
#MERGE WITH NDA PRODUCT DF
cms_2017_opioids_fin = pd.merge(cms_2017_opioids, nda_product, on='PRODUCTNDC', how='left')
#how many are missing
cms_2017_opioids_fin['PRODUCTID'].isnull().sum() #1840
len(cms_2017_opioids_fin) #5265 total records
# Out:
# 5265

# %%
cms_2017_opioids_fin.head()
# Out:
#   Utilization Type State  label_code  product_code  package_size  Year  \
# 0             FFSU    MI         409          1256             1  2017
# 1             FFSU    MN       59011           460            10  2017
# 2             FFSU    AK       63481           817            60  2017
# 3             MCOU    LA       59011           751             4  2017
# 4             FFSU    VT       50458            94             5  2017
#
#    Quarter product_name  suppression  units_reimb     ...       \
# 0        1      DEMEROL         True          NaN     ...
# 1        1    OXYCONTIN        False        961.0     ...
# 2        1     OPANA ER         True          NaN     ...
# 3        1      BUTRANS         True          NaN     ...
# 4        1    DURAGESIC         True          NaN     ...
#
#    STARTMARKETINGDATE  ENDMARKETINGDATE  MARKETINGCATEGORYNAME  \
# 0                 NaN               NaN                    NaN
# 1          20100808.0               NaN                    NDA
# 2          20120320.0        20191101.0                    NDA
# 3          20110214.0               NaN                    NDA
# 4                 NaN               NaN                    NaN
#
#    APPLICATIONNUMBER                 LABELERNAME              SUBSTANCENAME  \
# 0                NaN                         NaN                        NaN
# 1          NDA022272            Purdue Pharma LP    OXYCODONE HYDROCHLORIDE
# 2          NDA201655  Endo Pharmaceuticals, Inc.  OXYMORPHONE HYDROCHLORIDE
# 3          NDA021306            Purdue Pharma LP              BUPRENORPHINE
# 4                NaN                         NaN                        NaN
#
#    ACTIVE_NUMERATOR_STRENGTH  ACTIVE_INGRED_UNIT  \
# 0                        NaN                 NaN
# 1                         60                mg/1
# 2                         30                mg/1
# 3                         10                ug/h
# 4                        NaN                 NaN
#
#                                        PHARM_CLASSES  DEASCHEDULE
# 0                                                NaN          NaN
# 1    Full Opioid Agonists [MoA],Opioid Agonist [EPC]          CII
# 2    Full Opioid Agonists [MoA],Opioid Agonist [EPC]          CII
# 3  Partial Opioid Agonist [EPC],Partial Opioid Ag...         CIII
# 4                                                NaN          NaN
#
# [5 rows x 38 columns]

# %%
cms_2017_opioids_fin.dtypes
# Out:
# Utilization Type              object
# State                         object
# label_code                     int64
# product_code                   int64
# package_size                   int64
# Year                           int64
# Quarter                        int64
# product_name                  object
# suppression                     bool
# units_reimb                  float64
# num_rx                       float64
# total_amt_reimb              float64
# med_amt_reimb                float64
# nonmed_amt_reimb             float64
# qtr_begin                     object
# qtr_begin_date                object
# Latitude                     float64
# Longitude                    float64
# Location                      object
# NDC                            int64
# PRODUCTNDC                    object
# PRODUCTID                     object
# PRODUCTTYPENAME               object
# PROPRIETARYNAME               object
# PROPRIETARYNAMESUFFIX         object
# NONPROPRIETARYNAME            object
# DOSAGEFORMNAME                object
# ROUTENAME                     object
# STARTMARKETINGDATE           float64
# ENDMARKETINGDATE             float64
# MARKETINGCATEGORYNAME         object
# APPLICATIONNUMBER             object
# LABELERNAME                   object
# SUBSTANCENAME                 object
# ACTIVE_NUMERATOR_STRENGTH     object
# ACTIVE_INGRED_UNIT            object
# PHARM_CLASSES                 object
# DEASCHEDULE                   object
# dtype: object

# %%
#convert startmarketingdate and endmarketingdate to datetime
#startdate
cms_2017_opioids_fin['STARTMARKETINGDATE'].fillna(value=0, inplace=True)
cms_2017_opioids_fin['STARTMARKETINGDATE'] = map(lambda x: int(x), cms_2017_opioids_fin['STARTMARKETINGDATE'])
cms_2017_opioids_fin['STARTMARKETINGDATE'] = cms_2017_opioids_fin['STARTMARKETINGDATE'].apply(str)
cms_2017_opioids_fin['startdate'] = map(lambda x: x[0:4] + "-" + x[4:6] + "-" + x[6:], cms_2017_opioids_fin['STARTMARKETINGDATE'])
cms_2017_opioids_fin['startdate'].replace(to_replace='0--', value='1970-01-01', inplace=True)
cms_2017_opioids_fin['startdate'] = pd.to_datetime(cms_2017_opioids_fin['startdate'], format='%Y-%m-%d')

# %%
#enddate
cms_2017_opioids_fin['ENDMARKETINGDATE'].fillna(value=0, inplace=True)
cms_2017_opioids_fin['ENDMARKETINGDATE'] = map(lambda x: int(x), cms_2017_opioids_fin['ENDMARKETINGDATE'])
cms_2017_opioids_fin['ENDMARKETINGDATE'] = cms_2017_opioids_fin['ENDMARKETINGDATE'].apply(str)
cms_2017_opioids_fin['enddate'] = map(lambda x: x[0:4] + "-" + x[4:6] + "-" + x[6:], cms_2017_opioids_fin['ENDMARKETINGDATE'])
cms_2017_opioids_fin['enddate'].replace(to_replace='0--', value='1970-01-01', inplace=True)
cms_2017_opioids_fin['enddate'] = pd.to_datetime(cms_2017_opioids_fin['enddate'], format='%Y-%m-%d')

# %%
cms_2017_opioids_fin.dtypes
# Out:
# Utilization Type                     object
# State                                object
# label_code                            int64
# product_code                          int64
# package_size                          int64
# Year                                  int64
# Quarter                               int64
# product_name                         object
# suppression                            bool
# units_reimb                         float64
# num_rx                              float64
# total_amt_reimb                     float64
# med_amt_reimb                       float64
# nonmed_amt_reimb                    float64
# qtr_begin                            object
# qtr_begin_date                       object
# Latitude                            float64
# Longitude                           float64
# Location                             object
# NDC                                   int64
# PRODUCTNDC                           object
# PRODUCTID                            object
# PRODUCTTYPENAME                      object
# PROPRIETARYNAME                      object
# PROPRIETARYNAMESUFFIX                object
# NONPROPRIETARYNAME                   object
# DOSAGEFORMNAME                       object
# ROUTENAME                            object
# STARTMARKETINGDATE                   object
# ENDMARKETINGDATE                     object
# MARKETINGCATEGORYNAME                object
# APPLICATIONNUMBER                    object
# LABELERNAME                          object
# SUBSTANCENAME                        object
# ACTIVE_NUMERATOR_STRENGTH            object
# ACTIVE_INGRED_UNIT                   object
# PHARM_CLASSES                        object
# DEASCHEDULE                          object
# startdate                    datetime64[ns]
# enddate                      datetime64[ns]
# dtype: object

# %% [markdown]
# this dataframe: cms_2017_opioids_fin is what's in the hackathon repo.

# %% [markdown]
# <b>Some key stats</b>

# %%
#Pivot Table with Key STats
cms17_stats = pd.pivot_table(cms_2017_opioids_fin,index=["State", "Quarter", "startdate","product_name", "DOSAGEFORMNAME", "LABELERNAME", "ROUTENAME", "DEASCHEDULE", "ACTIVE_NUMERATOR_STRENGTH"], 
                                values=['units_reimb', 'num_rx', 'total_amt_reimb', 
                                        'med_amt_reimb', 'nonmed_amt_reimb'], 
               aggfunc={'units_reimb': lambda x: x.sum(), 
                        'num_rx': lambda x: x.sum(), 
                        'total_amt_reimb': lambda x: x.sum(),
                        'med_amt_reimb': lambda x: x.sum(),
                        'nonmed_amt_reimb':lambda x: x.sum()})

cms17_stats_fin = cms17_stats.reset_index()
cms17_stats_fin.rename(columns={'units_reimb': 'units_reimb_sum', 
                                'num_rx':'num_rx_sum', 
                                'total_amt_reimb':'total_amt_reimb_sum',
                                'med_amt_reimb':'med_amt_reimb_sum',
                                'nonmed_amt_reimb':'nonmed_amt_reimb_sum'}, inplace=True)
cms17_stats_fin.reset_index(inplace=True)

# %% [markdown]
# After talking to a doctor friend of mine, figured out that ACTIVE_NUMERATOR_STRENGTH is the dosage.

# %%
cms17_stats_fin['strength'] = cms17_stats_fin['ACTIVE_NUMERATOR_STRENGTH'].str.split(';').str[0]
cms17_stats_fin['strength'].fillna(value=0, inplace=True)
cms17_stats_fin['strength'] = map(lambda x: float(x), cms17_stats_fin['strength'])

# %%
cms17_stats_fin.head()
# Out:
#    index State  Quarter  startdate product_name                DOSAGEFORMNAME  \
# 0      0    AK        1 1956-01-01     DILAUDID                        TABLET
# 1      1    AK        1 1987-12-31    TUSSIONEX  SUSPENSION, EXTENDED RELEASE
# 2      2    AK        1 1997-06-25        NORCO                        TABLET
# 3      3    AK        1 2007-08-20     FENTANYL                         PATCH
# 4      4    AK        1 2007-08-20     FENTANYL                         PATCH
#
#                  LABELERNAME    ROUTENAME DEASCHEDULE  \
# 0           Purdue Pharma LP         ORAL         CII
# 1  Unither Manufacturing LLC         ORAL         CII
# 2       Actavis Pharma, Inc.         ORAL         CII
# 3    Par Pharmaceutical Inc.  TRANSDERMAL         CII
# 4    Par Pharmaceutical Inc.  TRANSDERMAL         CII
#
#   ACTIVE_NUMERATOR_STRENGTH  med_amt_reimb_sum  nonmed_amt_reimb_sum  \
# 0                         2                0.0                   0.0
# 1                     10; 8                0.0                   0.0
# 2                    5; 325                0.0                   0.0
# 3                       100                0.0                   0.0
# 4                        50                0.0                   0.0
#
#    num_rx_sum  total_amt_reimb_sum  units_reimb_sum  strength
# 0         0.0                  0.0              0.0       2.0
# 1         0.0                  0.0              0.0      10.0
# 2         0.0                  0.0              0.0       5.0
# 3         0.0                  0.0              0.0     100.0
# 4         0.0                  0.0              0.0      50.0

# %% [markdown]
# How much drugs have been reimbursed, providing us a proxy measure of legitimate hospital supply of drugs?  Multiply `units_reimb_sum` by `strength`.

# %%
cms17_stats_fin['legit_supply'] = cms17_stats_fin['units_reimb_sum'] * cms17_stats_fin['strength']
cms17_stats_fin.fillna(value=0, inplace=True)

# %%
supply_index_2017 = cms17_stats_fin[['State', 'Quarter', 'startdate','product_name', 'LABELERNAME', 'DOSAGEFORMNAME', 'ROUTENAME', 'legit_supply']]
supply_index_2017.head(25)
# Out:
#    State  Quarter  startdate product_name                         LABELERNAME  \
# 0     AK        1 1956-01-01     DILAUDID                    Purdue Pharma LP
# 1     AK        1 1987-12-31    TUSSIONEX           Unither Manufacturing LLC
# 2     AK        1 1997-06-25        NORCO                Actavis Pharma, Inc.
# 3     AK        1 2007-08-20     FENTANYL             Par Pharmaceutical Inc.
# 4     AK        1 2007-08-20     FENTANYL             Par Pharmaceutical Inc.
# 5     AK        1 2007-08-20     FENTANYL             Par Pharmaceutical Inc.
# 6     AK        1 2009-08-13       EMBEDA  Pfizer Laboratories Div Pfizer Inc
# 7     AK        1 2009-08-13       EMBEDA  Pfizer Laboratories Div Pfizer Inc
# 8     AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 9     AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 10    AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 11    AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 12    AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 13    AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 14    AK        1 2010-08-08    OXYCONTIN                    Purdue Pharma LP
# 15    AK        1 2011-02-14      BUTRANS                    Purdue Pharma LP
# 16    AK        1 2011-02-14      BUTRANS                    Purdue Pharma LP
# 17    AK        1 2011-02-14      BUTRANS                    Purdue Pharma LP
# 18    AK        1 2011-02-14      BUTRANS                    Purdue Pharma LP
# 19    AK        1 2011-02-14      BUTRANS                    Purdue Pharma LP
# 20    AK        1 2011-08-25   NUCYNTA ER       Janssen Pharmaceuticals, Inc.
# 21    AK        1 2011-08-25   NUCYNTA ER       Janssen Pharmaceuticals, Inc.
# 22    AK        1 2012-03-20     OPANA ER          Endo Pharmaceuticals, Inc.
# 23    AK        1 2012-03-20     OPANA ER          Endo Pharmaceuticals, Inc.
# 24    AK        1 2012-03-20     OPANA ER          Endo Pharmaceuticals, Inc.
#
#                            DOSAGEFORMNAME    ROUTENAME  legit_supply
# 0                                  TABLET         ORAL           0.0
# 1            SUSPENSION, EXTENDED RELEASE         ORAL           0.0
# 2                                  TABLET         ORAL           0.0
# 3                                   PATCH  TRANSDERMAL           0.0
# 4                                   PATCH  TRANSDERMAL           0.0
# 5                                   PATCH  TRANSDERMAL           0.0
# 6               CAPSULE, EXTENDED RELEASE         ORAL           0.0
# 7               CAPSULE, EXTENDED RELEASE         ORAL           0.0
# 8   TABLET, FILM COATED, EXTENDED RELEASE         ORAL       50340.0
# 9   TABLET, FILM COATED, EXTENDED RELEASE         ORAL       37860.0
# 10  TABLET, FILM COATED, EXTENDED RELEASE         ORAL      173200.0
# 11  TABLET, FILM COATED, EXTENDED RELEASE         ORAL      198780.0
# 12  TABLET, FILM COATED, EXTENDED RELEASE         ORAL       40440.0
# 13  TABLET, FILM COATED, EXTENDED RELEASE         ORAL      285360.0
# 14  TABLET, FILM COATED, EXTENDED RELEASE         ORAL           0.0
# 15                PATCH, EXTENDED RELEASE  TRANSDERMAL        1960.0
# 16                PATCH, EXTENDED RELEASE  TRANSDERMAL        2880.0
# 17                PATCH, EXTENDED RELEASE  TRANSDERMAL        4240.0
# 18                PATCH, EXTENDED RELEASE  TRANSDERMAL         610.0
# 19                PATCH, EXTENDED RELEASE  TRANSDERMAL           0.0
# 20  TABLET, FILM COATED, EXTENDED RELEASE         ORAL           0.0
# 21  TABLET, FILM COATED, EXTENDED RELEASE         ORAL           0.0
# 22               TABLET, EXTENDED RELEASE         ORAL           0.0
# 23               TABLET, EXTENDED RELEASE         ORAL           0.0
# 24               TABLET, EXTENDED RELEASE         ORAL           0.0

# %% [markdown]
# <b>Texas</b>

# %%
tx_supply = supply_index_2017.loc[(supply_index_2017['State'] == 'TX')]
tx_supply
# Out:
#      State  Quarter  startdate product_name                    LABELERNAME  \
# 2046    TX        1 1987-07-01    MS CONTIN               Purdue Pharma LP
# 2047    TX        1 1987-07-01    MS CONTIN               Purdue Pharma LP
# 2048    TX        1 1987-12-31    TUSSIONEX      Unither Manufacturing LLC
# 2049    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2050    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2051    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2052    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2053    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2054    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2055    TX        1 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2056    TX        1 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2057    TX        1 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2058    TX        1 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2059    TX        1 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2060    TX        1 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2061    TX        2 1987-07-01    MS CONTIN               Purdue Pharma LP
# 2062    TX        2 1987-07-01    MS CONTIN               Purdue Pharma LP
# 2063    TX        2 1987-07-01    MS CONTIN               Purdue Pharma LP
# 2064    TX        2 1987-12-31    TUSSIONEX      Unither Manufacturing LLC
# 2065    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2066    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2067    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2068    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2069    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2070    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2071    TX        2 2010-08-08    OXYCONTIN               Purdue Pharma LP
# 2072    TX        2 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2073    TX        2 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2074    TX        2 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2075    TX        2 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
# 2076    TX        2 2011-08-25   NUCYNTA ER  Janssen Pharmaceuticals, Inc.
#
#                              DOSAGEFORMNAME ROUTENAME  legit_supply
# 2046  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2047  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2048           SUSPENSION, EXTENDED RELEASE      ORAL           0.0
# 2049  TABLET, FILM COATED, EXTENDED RELEASE      ORAL       92640.0
# 2050  TABLET, FILM COATED, EXTENDED RELEASE      ORAL       59160.0
# 2051  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      291320.0
# 2052  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      303660.0
# 2053  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      411680.0
# 2054  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      541380.0
# 2055  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      804240.0
# 2056  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      234000.0
# 2057  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      126000.0
# 2058  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2059  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      240000.0
# 2060  TABLET, FILM COATED, EXTENDED RELEASE      ORAL       48000.0
# 2061  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2062  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2063  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2064           SUSPENSION, EXTENDED RELEASE      ORAL           0.0
# 2065  TABLET, FILM COATED, EXTENDED RELEASE      ORAL       83100.0
# 2066  TABLET, FILM COATED, EXTENDED RELEASE      ORAL       50190.0
# 2067  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      265540.0
# 2068  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      287340.0
# 2069  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      335480.0
# 2070  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      477840.0
# 2071  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      590160.0
# 2072  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      312900.0
# 2073  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      130500.0
# 2074  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0
# 2075  TABLET, FILM COATED, EXTENDED RELEASE      ORAL      209500.0
# 2076  TABLET, FILM COATED, EXTENDED RELEASE      ORAL           0.0

# %% [markdown]
# <b>CMS 2016 Data</b>

# %%
cms_2016 = pd.read_csv("/Users/catherineordun/Documents/Hackathon/DHHS/ready_data/State_Drug_Utilization_Data_2016.csv")
print(cms_2016.shape) #(4625479, 20)
cms_2016.rename(columns={
        'Labeler Code':'label_code',
        'Product Code':'product_code',
        'Package Size':'package_size',
        'Product Name':'product_name',
        'Suppression Used':'suppression',
        'Units Reimbursed':'units_reimb',
        'Number of Prescriptions':'num_rx',
        'Total Amount Reimbursed':'total_amt_reimb',
        'Medicaid Amount Reimbursed':'med_amt_reimb',
        'Non Medicaid Amount Reimbursed':'nonmed_amt_reimb',
        'Quarter Begin':'qtr_begin', 
        'Quarter Begin Date':'qtr_begin_date'},inplace=True)

#make sure all the product_names are capitalized in the dataframe so we get everything 
cms_2016['product_name'] = map(lambda x: str(x).upper(), cms_2016['product_name'])

#now search through to find a match
cms_2016_opioids = cms_2016.query('product_name in @cap_searchlist')
print(cms_2016_opioids['product_name'].nunique()) #33

#make a new column called 'PRODUCTNDC'
cms_2016_opioids['PRODUCTNDC'] = cms_2016_opioids['label_code'].astype(str) + '-' +cms_2016_opioids['product_code'].astype(str)

#check it's right
cms_2016_opioids.loc[(cms_2016_opioids["product_name"] == "ABSTRAL")] #ok it works
#MERGE WITH NDA PRODUCT DF
cms_2016_opioids_fin = pd.merge(cms_2016_opioids, nda_product, on='PRODUCTNDC', how='left')
len(cms_2016_opioids_fin) #11287
cms_2016_opioids_fin['PRODUCTID'].isnull().sum() #4039

#convert startmarketingdate and endmarketingdate to datetime
#startdate
cms_2016_opioids_fin['STARTMARKETINGDATE'].fillna(value=0, inplace=True)
cms_2016_opioids_fin['STARTMARKETINGDATE'] = map(lambda x: int(x), cms_2016_opioids_fin['STARTMARKETINGDATE'])
cms_2016_opioids_fin['STARTMARKETINGDATE'] = cms_2016_opioids_fin['STARTMARKETINGDATE'].apply(str)
cms_2016_opioids_fin['startdate'] = map(lambda x: x[0:4] + "-" + x[4:6] + "-" + x[6:], cms_2016_opioids_fin['STARTMARKETINGDATE'])
cms_2016_opioids_fin['startdate'].replace(to_replace='0--', value='1970-01-01', inplace=True)
cms_2016_opioids_fin['startdate'] = pd.to_datetime(cms_2016_opioids_fin['startdate'], format='%Y-%m-%d')

#enddate
cms_2016_opioids_fin['ENDMARKETINGDATE'].fillna(value=0, inplace=True)
cms_2016_opioids_fin['ENDMARKETINGDATE'] = map(lambda x: int(x), cms_2016_opioids_fin['ENDMARKETINGDATE'])
cms_2016_opioids_fin['ENDMARKETINGDATE'] = cms_2016_opioids_fin['ENDMARKETINGDATE'].apply(str)
cms_2016_opioids_fin['enddate'] = map(lambda x: x[0:4] + "-" + x[4:6] + "-" + x[6:], cms_2016_opioids_fin['ENDMARKETINGDATE'])
cms_2016_opioids_fin['enddate'].replace(to_replace='0--', value='1970-01-01', inplace=True)
cms_2016_opioids_fin['enddate'] = pd.to_datetime(cms_2016_opioids_fin['enddate'], format='%Y-%m-%d')
#send to csv
#cms_2016_opioids_fin.to_csv("/Users/catherineordun/Documents/Hackathon/DHHS/final_datasets/cms_2016_opioids_fin.csv")
#Pivot Table with Key STats
cms16_stats = pd.pivot_table(cms_2016_opioids_fin,index=["State", "Quarter", "product_name", "DOSAGEFORMNAME", "LABELERNAME", "ROUTENAME", "DEASCHEDULE", "ACTIVE_NUMERATOR_STRENGTH"], 
                                values=['units_reimb', 'num_rx', 'total_amt_reimb', 
                                        'med_amt_reimb', 'nonmed_amt_reimb'], 
               aggfunc={'units_reimb': lambda x: x.sum(), 
                        'num_rx': lambda x: x.sum(), 
                        'total_amt_reimb': lambda x: x.sum(),
                        'med_amt_reimb': lambda x: x.sum(),
                        'nonmed_amt_reimb':lambda x: x.sum()})

cms16_stats_fin = cms16_stats.reset_index()
cms16_stats_fin.rename(columns={'units_reimb': 'units_reimb_sum', 
                                'num_rx':'num_rx_sum', 
                                'total_amt_reimb':'total_amt_reimb_sum',
                                'med_amt_reimb':'med_amt_reimb_sum',
                                'nonmed_amt_reimb':'nonmed_amt_reimb_sum'}, inplace=True)
cms16_stats_fin.reset_index(inplace=True)
    
cms16_stats_fin['strength'] = cms16_stats_fin['ACTIVE_NUMERATOR_STRENGTH'].str.split(';').str[0]
cms16_stats_fin['strength'].fillna(value=0, inplace=True)
cms16_stats_fin['strength'] = map(lambda x: float(x), cms16_stats_fin['strength'])

# %%
cms16_stats_fin.head()
